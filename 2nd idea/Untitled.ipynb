# %%
import pandas as pd

# %%
data = pd.read_csv('us_equities_news_dataset.csv')

# %%
aapl_data = data[data['ticker'] == 'AAPL']

# %%
aapl_data[aapl_data['category'] == 'news']
# Out:
#            id ticker                                              title  \
# 49183  270698   AAPL          JPMorgan cautious ahead of Apple earnings
# 49184  270699   AAPL        FAANG s Fall  but Get Some Wall Street Love
# 49185  270700   AAPL  Wall Street tumbles as virus fuels economic worry
# 49186  270701   AAPL  Earnings Watch  Apple and AMD to take earnings...
# 49187  270702   AAPL        Day Ahead  Top 3 Things to Watch for Jan 28
# ...       ...    ...                                                ...
# 62753  284268   AAPL  U S  stocks slide ahead of ISM data  Dow Jones...
# 62754  284269   AAPL  U S  futures rise although Fed uncertainty rem...
# 62755  284270   AAPL  U S  stocks open higher  Fed tapering in focus...
# 62756  284271   AAPL  U S  futures edge higher ahead of nonfarm payr...
# 62757  284272   AAPL  U S  stocks open higher after payrolls data  D...
#
#       category                                            content  \
# ...

# %%
data.groupby('release_date').sum()
# Out:
#                     id  article_id
# release_date
# 2008-10-02      227750         669
# 2008-10-03     1646462        2712
# 2008-10-06      851265        1428
# 2008-10-07      585155        1482
# 2008-10-08      320023         771
# ...                ...         ...
# 2020-02-09    24293654  7660828976
# 2020-02-10    31214464  7295214722
# 2020-02-11    31784527  6900486370
# 2020-02-12    18706240  4456955779
# 2020-02-13    17953142  2268072741
#
# [3641 rows x 2 columns]
